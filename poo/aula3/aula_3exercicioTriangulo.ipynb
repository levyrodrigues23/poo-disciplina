# %%
import math
import random


while True:

  QntdCordenada = input("digite A se voce quer adicionar 6 cordenadas para tres pontos, B se voce preferir 8 cordenadas para 4 pontos, C para sugestões de cordenadas para triangulo ou S para sair(A/B/C/S):")
  if QntdCordenada.lower().strip() == "a":
    print("voce escolheu 3 pontos, então, escolha 3 cordenadas x e 3 cordenadas y")
    
    y1 = int(input("digite o ponto y da cordenada 1 :"))
    x1 = int(input("digite o ponto x da cordenada 1 :"))
    y2 = int(input("digite o ponto y da cordenada 2 :"))
    x2 = int(input("digite o ponto x da cordenada 2 :"))
    y3 = int(input("digite o ponto y da cordenada 3 :"))
    x3 = int(input("digite o ponto x da cordenada 3 :"))

    areaModulo = abs((x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2))) / 2
    if areaModulo == 0:
      print("isso definitivamente não é um triangulo ")
      continue
    lado1 = int(math.sqrt((x2 - x1)**2 + (y2 - y1)**2))
    lado2 = int(math.sqrt((x3 - x2)**2 + (y3 - y2)**2))
    lado3 = int(math.sqrt((x1 - x3)**2 + (y1 - y3)**2))

    if lado1 == lado2 and lado2 == lado3 and lado3 == lado1:
          print(" este é um triangulo equilatero")
    elif lado1 == lado2 or lado2 == lado3 or lado1 == lado3:
          print("este é um triagulo isosceles")
    elif lado1 != lado2 and lado2 != lado3 and lado1 != lado3:
          print(" este é um trianulo escaleno")
  
  elif QntdCordenada.lower().strip() == "b":
    print("voce escolheu 4 pontos, então, escolha 4 cordenadas x e 4 cordenadas y")
    
    y1 = int(input("digite o ponto y da cordenada 1 :"))
    x1 = int(input("digite o ponto x da cordenada 1 :"))
    y2 = int(input("digite o ponto y da cordenada 2 :"))
    x2 = int(input("digite o ponto x da cordenada 2 :"))
    y3 = int(input("digite o ponto y da cordenada 3 :"))
    x3 = int(input("digite o ponto x da cordenada 3 :"))
    y4 = int(input("digite o ponto y da cordenada 4 :"))
    x4 = int(input("digite o ponto x da cordenada 4 :"))
    
    ladoAB = int(math.sqrt((x2 - x1)**2 + (y2 - y1)**2))
    ladoBC = int(math.sqrt((x3 - x2)**2 + (y3 - y2)**2))
    ladoCD = int(math.sqrt((x4 - x3)**2 + (y4 - y3)**2))
    ladoDA = int(math.sqrt((x1 - x4)**2 + (y1 - y4)**2))
    diagonalAC = int(math.sqrt((x3 - x1)**2 + (y3 - y1)**2))
    diagonalBD = int(math.sqrt((x4 - x2)**2 + (y4 - y2)**2))
    
    if ladoAB == ladoBC and ladoBC == ladoCD and ladoCD == ladoDA and ladoDA == ladoAB and ladoAB == ladoCD and diagonalAC == diagonalBD:
      print("isso é claramente um quadrado.")
    elif ladoAB == ladoCD and ladoBC == ladoDA and diagonalAC == diagonalBD:
      print("isso é claramente um retângulo.")
    elif ladoAB == ladoBC == ladoCD == ladoDA and diagonalAC != diagonalBD:
      print("isso é claramente um losango.")
    elif ladoAB == ladoCD and ladoBC == ladoDA and diagonalAC != diagonalBD:
      print("isso é um paralelogramo")
    else:
      print("isso é um quadrilátero irregular")
      
      # ainda não foi implementado a lógica para identificar trapézios, envolve mais cálculos geométricos e entra a parte da inclinação.
  
  elif QntdCordenada.lower().strip() == "c":
    print("voce escolheu coordenadas aleatórias para triangulo")
    tipoTriangulo = input("voce deseja coordenadas para um triângulo equilátero, isósceles ou escaleno? (E/I/S):")
    
    if tipoTriangulo.lower().strip() == "e":
      print("Coordenadas aleatórias para triângulo EQUILÁTERO:")
      equilateros_base = [
        [(0, 0), (3, 0), (1, 3)],
        [(1, 1), (4, 1), (2, 4)],
        [(2, 2), (5, 2), (3, 5)],
        [(0, 1), (3, 1), (1, 4)],
      ]
      coords_base = random.choice(equilateros_base)
      
      y1, x1 = coords_base[0]
      y2, x2 = coords_base[1]
      y3, x3 = coords_base[2]
      
    elif tipoTriangulo.lower().strip() == "i":
      print("Coordenadas aleatórias para triângulo ISÓSCELES:")
      isosceles_base = [
        [(0, 0), (6, 0), (3, 4)],
        [(0, 0), (8, 0), (4, 3)],
        [(1, 1), (7, 1), (4, 4)],
        [(0, 1), (6, 1), (3, 5)],
      ]
      coords_base = random.choice(isosceles_base)
      
      y1, x1 = coords_base[0]
      y2, x2 = coords_base[1]
      y3, x3 = coords_base[2]
      
    elif tipoTriangulo.lower().strip() == "s":
      print("Coordenadas aleatórias para triângulo ESCALENO:")
      escalenos_base = [
        [(0, 0), (3, 0), (0, 4)],
        [(0, 0), (5, 0), (0, 12)],
        [(1, 1), (6, 1), (1, 8)],
        [(0, 1), (7, 1), (2, 6)],
      ]
      coords_base = random.choice(escalenos_base)
      
      y1, x1 = coords_base[0]
      y2, x2 = coords_base[1]
      y3, x3 = coords_base[2]
      
    else:
      print("voce não selecionou uma opção adequada, tente novamente")
      continue
    
    print(f"y1 = {y1}, x1 = {x1}")
    print(f"y2 = {y2}, x2 = {x2}")
    print(f"y3 = {y3}, x3 = {x3}")
    
    lado1 = int(math.sqrt((x2 - x1)**2 + (y2 - y1)**2))
    lado2 = int(math.sqrt((x3 - x2)**2 + (y3 - y2)**2))
    lado3 = int(math.sqrt((x1 - x3)**2 + (y1 - y3)**2))
    print(f"Lados calculados: {lado1}, {lado2}, {lado3}")
  
  elif QntdCordenada.lower().strip() == "s":
    print("Tudo bem, tenha um ótimo dia!")
    break
